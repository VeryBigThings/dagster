# %%
from etl.notebooks.common import load_parquet
import pandas as pd

pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
pd.set_option('display.max_rows', 500)

# %%
# df = load_parquet("production", "tlkpCustomer")

# %%
# select only customers that contain the word "Essity" in their name
# df[df["Customer"].str.contains("Essity")]

# %%
df = load_parquet("ctc_config", "ctc_limit_audit")
# sort by actiontime
# df = df.sort_values("actiontime", ascending=False)
# df.head(100)
df
# sum RollWeight by MachineNumber

# df_bill.groupby("MachineNumber")["RollWeight"].sum()
# Out:
#            auditid  limitid  specid  limittypeid  lower_limit  target  upper_limit  lower_flag  upper_flag lower_utag target_utag upper_utag  utag_flag                             changenote auditaction               audittime     auditby
# 0       1431845072     7983    2102            2        550.0   750.0          NaN           1           1       None        None       None          0  Updated by SQL Job from Manual Logger      UPDATE 2024-11-27 04:05:28.807      SQLJOB
# 1       1431845071     3443    2102            2        550.0   750.0          NaN           1           1       None        None       None          0  Updated by SQL Job from Manual Logger    Modified 2024-11-27 04:05:28.807  HISTS\ajay
# 2       1431845070     7983    3044            2        290.0   360.0          NaN           1           1       None        None       None          0  Updated by SQL Job from Manual Logger      UPDATE 2024-11-27 04:05:28.797      SQLJOB
# ...
